# %%
# !nvidia-smi
# Out:
# Mon Dec 25 10:00:53 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 7.3 MB/s eta 0:00:00
# ...

# %%
import os
import shutil
import random

# !pip install tqdm --upgrade
from tqdm.notebook import tqdm

# %%
import ultralytics
ultralytics.checks()

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/YOLOv8/dataset.yaml epochs=10 imgsz=640 batch=8 project=/content/drive/MyDrive/YOLOv8/RESULTS name=football

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/YOLOv8/RESULTS/football/weights/best.pt conf=0.55 source=/content/drive/MyDrive/YOLOv8/TEST

# %%
# !cp -r /content/runs/detect/predict3 /content/drive/MyDrive/YOLOv8/OUTPUT

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/YOLOv8/RESULTS/football/weights/best.pt conf=0.55 source=/content/drive/MyDrive/YOLOv8/vids

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/YOLOv8/dataset.yaml epochs=25 imgsz=640 batch=8 project=/content/drive/MyDrive/YOLOv8/RESULTS name=football

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/YOLOv8/RESULTS/football2/weights/best.pt conf=0.55 source=/content/drive/MyDrive/YOLOv8/TEST

# %%
# !cp -r /content/runs/detect/predict6 /content/drive/MyDrive/YOLOv8/OUTPUT

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/YOLOv8/RESULTS/football2/weights/best.pt conf=0.55 source=/content/drive/MyDrive/YOLOv8/vids

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/YOLOv8/dataset.yaml epochs=10 imgsz=640 batch=8 project=/content/drive/MyDrive/YOLOv8/RESULTS name=football

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/YOLOv8/RESULTS/football6/weights/best.pt conf=0.55 source=/content/drive/MyDrive/YOLOv8/TEST
